# %% [markdown]
# ## Funções
#
# ### Lambda
#
# Pequenas **funções anônimas** que podem ser criadas com a palavra-chave **lambda**
#
# ```python
#     sqrt = lambda x: x ** (1/2)
# ```

# %%
sqrt = lambda x: x ** (1/2)

# %%
sqrt(100)
# Out:
# 10.0
