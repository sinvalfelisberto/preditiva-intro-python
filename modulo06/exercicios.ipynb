# %% [markdown]
# ## Exercicio 1
# <br>
#
# **Problema:** <p>Crie uma função para obter o valor do dólar diário.</p>
# <br>
# Para executar esta tarefa considere que sua fonte será a API do Bacen:
# https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarDia(dataCotacao=@dataCotacao)?@dataCotacao='{Data}'&$format=json
#
# Substitua ```{Data}``` pela data de interesse no formato mês-dia-ano
#
# Para construir sua função utilize recursos já existentes, ou seja, use algum módulo do Python que te permita fazer a requisição de uma API.
# *Dica:* requests e urllib3 são duas alternativas de pacotes para este trabalho e você pode também precisar utilizar o módulo json

# %%
data = data = '07-08-2024'

url = f'https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarDia(dataCotacao=@dataCotacao)?@dataCotacao={data}&$format=json'

# %%
url
# Out:
# 'https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarDia(dataCotacao=@dataCotacao)?@dataCotacao=07-08-2024&$format=json'
